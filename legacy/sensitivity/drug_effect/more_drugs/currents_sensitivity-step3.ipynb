# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import json
from functions import *
import pandas as pd
import csv

def get_currents(file):
    def read_currents_file(filepath):
        # Read the file content
        with open(filepath, 'r') as file:
            # Read the first line to get current names
            header_line = file.readline().strip()
            
            # Split the header first by semicolons, then by commas
            current_groups = header_line.split(';')
            current_names = []
            for group in current_groups:
                currents = [name.strip() for name in group.split(',')]
                current_names.extend(currents)
                
            # Initialize dictionary with empty lists for each current
            data_dict = {name: [] for name in current_names}
            
            # Read the rest of the lines
            for line in file:
                # if start with undefined,skip
                if line.startswith("undefined"):
                    continue
                if not line.strip():  # Skip empty lines
                    continue
                
                # Split values by semicolon first, then comma
                value_groups = line.strip().split(';')
                values = []
                for group in value_groups:
                    group_values = [float(val.strip()) for val in group.split(',') if val.strip()]
                    values.extend(group_values)
                
                # Add each value to corresponding current's list
                for name, value in zip(current_names, values):
                    data_dict[name].append(value)
        
        # Convert lists to numpy arrays for easier manipulation
        for name in data_dict:
            data_dict[name] = np.array(data_dict[name])
        
        return data_dict

    # Example usage:
    filepath = file
    currents_data = read_currents_file(filepath)
    return currents_data
def readFile(file,unidentifiable_space = [3,5,6,7,8,9,10,11]):
    if not unidentifiable_space:
        unidentifiable_space = list(range(12))
    currents_data = get_currents(file)
    mask =  -100< currents_data['voltage']
    if 'NA' in currents_data:
        del currents_data['NA']
    matrix = np.zeros((len(currents_data['voltage'][mask]),len(currents_data)-1))  # Exclude voltage
    # assign currents to matrix columns
    for i, (current_name, values) in enumerate(currents_data.items()):
        if current_name not in ['voltage']:
            matrix[:, i - (1 if 'voltage' in currents_data else 0)] = values[mask]
    U, S, V = np.linalg.svd(matrix)
    def projection_S(v):
        ps = [0] * len(S)
        for i in unidentifiable_space:
            ps += np.inner(v,V[i]) / np.inner(V[i],V[i]) * V[i]
        return ps
    identifiability = {}
    for i, (current_name, values) in enumerate(currents_data.items()):
        if current_name in ['voltage']:
            continue
        v_I = [0]*len(S)
        v_I[i-1] = 1
        k = np.linalg.norm(v_I-projection_S(v_I))
        identifiability[current_name] = k
    sorted_identifiability = dict(sorted(identifiability.items(), key=lambda item: item[1], reverse=True))
    return U,S,V,currents_data,sorted_identifiability
def plot_sorted_currents_with_identifiability(currents_data, sorted_identifiability):
    # Get currents in sorted order (already sorted by identifiability)
    currents_to_plot = list(sorted_identifiability.keys())
    n_currents = len(currents_to_plot)
    
    # Create figure with special grid
    fig = plt.figure(figsize=(15, 4*(n_currents//3 + 2)))  # +2 for voltage row
    
    # Create grid with different row heights
    gs = plt.GridSpec(n_currents//3 + 2, 3, height_ratios=[1.5] + [1]*(n_currents//3 + 1))
    
    # Plot voltage across entire first row
    ax_voltage = fig.add_subplot(gs[0, :])
    ax_voltage.plot(currents_data['voltage'], 'b-')
    ax_voltage.set_title('Voltage')
    ax_voltage.set_ylabel('mV')
    ax_voltage.set_xlabel('Time Step')
    ax_voltage.grid(True)
    
    # Plot currents in remaining grid
    for idx, current_name in enumerate(currents_to_plot):
        row = (idx // 3) + 1  # +1 because voltage took first row
        col = idx % 3
        ax = fig.add_subplot(gs[row, col])
        
        # Plot the current
        ax.plot(currents_data[current_name], 'b-')
        
        # Set title with identifiability value
        identifiability_value = sorted_identifiability[current_name]
        def format_current_name(name):
            # Dictionary for special current name formatting
            current_formats = {
                'INa': 'I_{Na}',
                'ICaL': 'I_{CaL}',
                'Ito': 'I_{to}',
                'IKr': 'I_{Kr}',
                'IKs': 'I_{Ks}',
                'IK1': 'I_{K1}',
                'INaCa': 'I_{NaCa}',
                'INaK': 'I_{NaK}',
                'INab': 'I_{Nab}',
                'ICab': 'I_{Cab}',
                'IKb': 'I_{Kb}',
                'IpCa': 'I_{pCa}',
                'INalate': 'I_{Na,late}'
            }
            return current_formats.get(name, name)  # Return formatted name or original if not in dictionary

        # Then modify the title setting line to:
        ax.set_title(f'${format_current_name(current_name)}$\nIdentifiability: {identifiability_value:.3f}',fontsize=20)        
        ax.set_ylabel('Current (pA/pF)')
        ax.set_xlabel('Time Step')
        ax.grid(True)
    
    #plt.tight_layout()
    #plt.savefig('currents_sorted_by_identifiability.png', dpi=300)
    #plt.show()
    plt.close()
def get_voltage(vec,epsilon,pacing_period,drug_name):
    path = f"./data/voltage_vector{vec}_epsilon_{epsilon}_pacingPeriod_{pacing_period}_drug_name_{drug_name}.csv"
    voltage = np.array([])
    with open(path) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=';')
        for row in csv_reader:
            voltage = np.append(voltage, float(row[1]))
    return voltage

def dvdt_max(voltage):
    return np.max(np.gradient(voltage)) / dt
def euclidian_norm(v):
    return np.linalg.norm(v)

def H_test(v_star,v_bar):
    H1 = abs(get_APD_from_voltage(v_star,0.7,dt)[0] - get_APD_from_voltage(v_bar,0.7,dt)[0]) / abs(get_APD_from_voltage(v_star,0.7,dt)[0])
    H2 = abs(get_APD_from_voltage(v_star,0.5,dt)[0] - get_APD_from_voltage(v_bar,0.5,dt)[0]) / abs(get_APD_from_voltage(v_star,0.5,dt)[0])       
    H3 = abs(get_APD_from_voltage(v_star,0.2,dt)[0] - get_APD_from_voltage(v_bar,0.2,dt)[0]) / abs(get_APD_from_voltage(v_star,0.2,dt)[0])
    H4 = abs(dvdt_max(v_star) - dvdt_max(v_bar)) / abs(dvdt_max(v_star))
    H5 = np.linalg.norm(v_star - v_bar) / np.linalg.norm(v_star)
    return H1 + H2 + H3 + H4 + H5
    
def calculate_unidentifiable_space(pacing_period,drug_name):
    voltage_file = f'2D-TNNP-pacing-period-{pacing_period}/voltage_TNNP_pacingPeriod_{pacing_period}_{drug_name}.csv'
    vec_lst = list(range(12))
    epsilon_list = [-0.5,0.5]
    Delta = 0.25
    output = list(range(12))
    for vec in vec_lst:
        for epsilon in epsilon_list:            
            v_star = get_currents(voltage_file)['voltage']
            v_bar = get_voltage(vec,epsilon,pacing_period,drug_name)
            H_value = H_test(v_star,v_bar[1:])
            if H_value > Delta:
                # remove vec from output
                output.remove(vec)
                break
    return output

# %%
#calculate unidentifiable space
dt = 0.2

# %%
def get_IIC(drug_name,pacing_period):   
    file = f'2D-TNNP-pacing-period-{pacing_period}/voltage_TNNP_pacingPeriod_{pacing_period}_{drug_name}.csv'
    unidentifiable_space = calculate_unidentifiable_space(pacing_period,drug_name)
    print(f"Unidentifiable space for drug {drug_name} at pacing period {pacing_period}: {unidentifiable_space}")
    U,S,V,currents_data, sorted_identifiability = readFile(file,unidentifiable_space)
    return sorted_identifiability

# %%
pacing_period = 1000
folder = f"2D-TNNP-pacing-period-{pacing_period}"
# and find the pkl file
pkl_files = [f for f in os.listdir(folder) if f.endswith('.pkl')]

for file in pkl_files:
    with open(os.path.join(folder, file), 'rb') as f:
        drug_dict = pickle.load(f)

# %%
IIC_dict = {}
for drug_name in drug_dict.keys():
    if 'INaL' in drug_dict[drug_name]:
        print(f"Skipping simulation for {drug_name} due to INaL involvement...")
        continue
    sorted_identifiability = get_IIC(drug_name,pacing_period)
    IIC_dict[drug_name] = sorted_identifiability

# save IIC_dict as pkl file to certain folder
with open(os.path.join('data', f'IIC_dict_pacing_period_{pacing_period}.pkl'), 'wb') as f:
    pickle.dump(IIC_dict, f)
# Out:
# Unidentifiable space for drug Amiodarone I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Amiodarone II due to INaL involvement...
# Unidentifiable space for drug Astemizole at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug BaCl2 at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Bepridil I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Bepridil II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Bepridil III due to INaL involvement...
# Unidentifiable space for drug Ceftriaxone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Chloropromazine I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Chloropromazine II due to INaL involvement...
# Unidentifiable space for drug Cilostazol at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Cisapride I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Cisapride II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Clozapine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Dasatinib at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Diazepam at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Diltiazem I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Diltiazem II at pacing period 1000: [5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Disopyramide at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Dofetilide I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Dofetilide II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Dofetilide III at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Donepezil at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Droperidol at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Duloxetine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Flecainide I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Flecainide II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Flecainide III due to INaL involvement...
# Unidentifiable space for drug Halofantrine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Haloperidol at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Ibutilide at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Lamivudine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Lidocaine I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Lidocaine II due to INaL involvement...
# Unidentifiable space for drug Linezolid at pacing period 1000: [5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Loratadine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Methadone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Metronidazole at pacing period 1000: [5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Mexiletine I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Mexiletine II due to INaL involvement...
# Unidentifiable space for drug Mibefradil I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Mibefradil II due to INaL involvement...
# Unidentifiable space for drug Mitoxantrone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Moxifloxacin I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Moxifloxacin II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Moxifloxacin III due to INaL involvement...
# Unidentifiable space for drug Nifedinipine at pacing period 1000: [5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Nilotinib I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Nilotinib II due to INaL involvement...
# Unidentifiable space for drug Nimodipine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Nisoldipine due to INaL involvement...
# Unidentifiable space for drug Nitrendipine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Paliperidone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Paroxetine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Pentobarbital at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Phenytoin at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Pimozide at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Piperacillin at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Primidone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Procainamide at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Quinidine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Raltegravir at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Ranolazine due to INaL involvement...
# Unidentifiable space for drug Ribavirin at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Risperidone at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Saquinavir due to INaL involvement...
# Unidentifiable space for drug Sertindole I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sertindole II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sitagliptin at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Solifenacin at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sotalol I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sotalol II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sparfloxacin I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sparfloxacin II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Sunitinib at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Telbivudine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Terfenadine I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Terfenadine II at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Terodiline at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Thioridazine at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Verapamil I at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Skipping simulation for Verapamil II due to INaL involvement...
# Unidentifiable space for drug Verapamil III at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug Voriconazole at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug test1(cisapride) at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug test2(verapamil) at pacing period 1000: [5, 6, 7, 8, 9, 10, 11]
# Unidentifiable space for drug test3(none) at pacing period 1000: [3, 5, 6, 7, 8, 9, 10, 11]

# %%
# print IIC_dict, all details and save digits after decimal point to 3
for drug_name, identifiability in IIC_dict.items():
    print(f"Drug: {drug_name}")
    for current, value in identifiability.items():
        print(f"  {current}: {value:.3f}")
# Out:
# Drug: Amiodarone I
#   INa: 1.000
#   Ito: 0.958
#   ICaL: 0.880
#   IKs: 0.837
#   IpK: 0.543
#   IKr: 0.359
#   INaK: 0.340
#   INaCa: 0.207
#   IK1: 0.124
#   IbCa: 0.077
#   IpCa: 0.059
#   IbNa: 0.026
# Drug: Astemizole
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.876
#   IKs: 0.842
#   IpK: 0.621
#   INaK: 0.309
#   IKr: 0.286
#   INaCa: 0.181
#   IK1: 0.117
#   IbCa: 0.061
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: BaCl2
#   INa: 1.000
#   Ito: 0.951
#   ICaL: 0.876
#   IKs: 0.827
#   IpK: 0.613
#   IKr: 0.328
#   INaK: 0.311
#   INaCa: 0.200
#   IK1: 0.125
#   IbCa: 0.065
#   IpCa: 0.058
#   IbNa: 0.022
# Drug: Bepridil I
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.875
#   IKs: 0.855
#   IpK: 0.624
#   INaK: 0.311
#   IKr: 0.245
#   INaCa: 0.171
#   IK1: 0.116
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Bepridil II
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.875
#   IKs: 0.852
#   IpK: 0.621
#   INaK: 0.311
#   IKr: 0.257
#   INaCa: 0.172
#   IK1: 0.116
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Ceftriaxone
#   INa: 1.000
#   Ito: 0.958
#   ICaL: 0.881
#   IKs: 0.823
#   IpK: 0.544
#   IKr: 0.387
#   INaK: 0.335
#   INaCa: 0.216
#   IK1: 0.122
#   IbCa: 0.078
#   IpCa: 0.058
#   IbNa: 0.027
# Drug: Chloropromazine I
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.828
#   IpK: 0.611
#   IKr: 0.327
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Cilostazol
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.829
#   IpK: 0.612
#   IKr: 0.324
#   INaK: 0.308
#   INaCa: 0.189
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Cisapride I
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.876
#   IKs: 0.842
#   IpK: 0.621
#   INaK: 0.309
#   IKr: 0.284
#   INaCa: 0.180
#   IK1: 0.117
#   IbCa: 0.061
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Cisapride II
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.875
#   IKs: 0.844
#   IpK: 0.623
#   INaK: 0.309
#   IKr: 0.277
#   INaCa: 0.179
#   IK1: 0.117
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Clozapine
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.879
#   IKs: 0.831
#   IpK: 0.605
#   IKr: 0.325
#   INaK: 0.311
#   INaCa: 0.188
#   IK1: 0.119
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Dasatinib
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.611
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Diazepam
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.610
#   IKr: 0.330
#   INaK: 0.308
#   INaCa: 0.191
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Diltiazem I
#   INa: 1.000
#   Ito: 0.957
#   ICaL: 0.881
#   IKs: 0.816
#   IpK: 0.549
#   IKr: 0.398
#   INaK: 0.332
#   INaCa: 0.219
#   IK1: 0.122
#   IbCa: 0.078
#   IpCa: 0.058
#   IbNa: 0.027
# Drug: Diltiazem II
#   INa: 1.000
#   Ito: 0.988
#   ICaL: 0.921
#   IK1: 0.789
#   INaCa: 0.700
#   IKr: 0.685
#   INaK: 0.556
#   IKs: 0.390
#   IbCa: 0.320
#   IbNa: 0.115
#   IpK: 0.112
#   IpCa: 0.063
# Drug: Disopyramide
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.877
#   IKs: 0.835
#   IpK: 0.616
#   INaK: 0.308
#   IKr: 0.306
#   INaCa: 0.184
#   IK1: 0.118
#   IbCa: 0.062
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Dofetilide I
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.877
#   IKs: 0.835
#   IpK: 0.616
#   INaK: 0.308
#   IKr: 0.308
#   INaCa: 0.185
#   IK1: 0.119
#   IbCa: 0.062
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Dofetilide II
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.833
#   IpK: 0.614
#   IKr: 0.313
#   INaK: 0.308
#   INaCa: 0.186
#   IK1: 0.119
#   IbCa: 0.063
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Dofetilide III
#   INa: 1.000
#   Ito: 0.953
#   IKs: 0.884
#   ICaL: 0.868
#   IpK: 0.637
#   INaK: 0.309
#   INaCa: 0.152
#   IKr: 0.118
#   IK1: 0.113
#   IpCa: 0.057
#   IbCa: 0.056
#   IbNa: 0.018
# Drug: Donepezil
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.829
#   IpK: 0.612
#   IKr: 0.325
#   INaK: 0.308
#   INaCa: 0.189
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Droperidol
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.875
#   IKs: 0.850
#   IpK: 0.625
#   INaK: 0.309
#   IKr: 0.260
#   INaCa: 0.175
#   IK1: 0.116
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Duloxetine
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.611
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.191
#   IK1: 0.120
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Flecainide I
#   INa: 1.000
#   Ito: 0.928
#   ICaL: 0.872
#   IKs: 0.864
#   IpK: 0.642
#   INaK: 0.335
#   IKr: 0.220
#   INaCa: 0.181
#   IK1: 0.139
#   IbCa: 0.067
#   IpCa: 0.061
#   IbNa: 0.022
# Drug: Flecainide II
#   INa: 1.000
#   Ito: 0.949
#   ICaL: 0.872
#   IKs: 0.865
#   IpK: 0.629
#   INaK: 0.319
#   IKr: 0.212
#   INaCa: 0.166
#   IK1: 0.119
#   IbCa: 0.061
#   IpCa: 0.058
#   IbNa: 0.020
# Drug: Halofantrine
#   INa: 1.000
#   Ito: 0.958
#   ICaL: 0.878
#   IKs: 0.858
#   IpK: 0.592
#   INaK: 0.323
#   IKr: 0.264
#   INaCa: 0.171
#   IK1: 0.117
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Haloperidol
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.877
#   IKs: 0.835
#   IpK: 0.616
#   INaK: 0.308
#   IKr: 0.306
#   INaCa: 0.184
#   IK1: 0.118
#   IbCa: 0.062
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Ibutilide
#   INa: 1.000
#   Ito: 0.951
#   IKs: 0.900
#   ICaL: 0.860
#   IpK: 0.637
#   INaK: 0.308
#   INaCa: 0.150
#   IK1: 0.125
#   IpCa: 0.058
#   IbCa: 0.056
#   IbNa: 0.018
#   IKr: 0.012
# Drug: Lamivudine
#   INa: 1.000
#   Ito: 0.958
#   ICaL: 0.880
#   IKs: 0.742
#   IKr: 0.565
#   INaK: 0.385
#   IpK: 0.364
#   INaCa: 0.332
#   IK1: 0.156
#   IbCa: 0.129
#   IpCa: 0.060
#   IbNa: 0.046
# Drug: Lidocaine I
#   INa: 1.000
#   Ito: 0.949
#   ICaL: 0.877
#   IKs: 0.828
#   IpK: 0.617
#   IKr: 0.327
#   INaK: 0.312
#   INaCa: 0.192
#   IK1: 0.123
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Linezolid
#   INa: 1.000
#   Ito: 0.985
#   ICaL: 0.924
#   IK1: 0.735
#   IKs: 0.675
#   IKr: 0.650
#   INaCa: 0.631
#   INaK: 0.471
#   IpK: 0.266
#   IbCa: 0.235
#   IbNa: 0.085
#   IpCa: 0.065
# Drug: Loratadine
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.611
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.191
#   IK1: 0.120
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Methadone
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.876
#   IKs: 0.843
#   IpK: 0.622
#   INaK: 0.309
#   IKr: 0.282
#   INaCa: 0.180
#   IK1: 0.117
#   IbCa: 0.061
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Metronidazole
#   INa: 1.000
#   Ito: 0.984
#   ICaL: 0.914
#   IK1: 0.806
#   INaCa: 0.702
#   IKr: 0.650
#   INaK: 0.559
#   IKs: 0.431
#   IbCa: 0.316
#   IpK: 0.134
#   IbNa: 0.114
#   IpCa: 0.065
# Drug: Mexiletine I
#   INa: 1.000
#   Ito: 0.950
#   ICaL: 0.876
#   IKs: 0.815
#   IpK: 0.613
#   IKr: 0.347
#   INaK: 0.321
#   INaCa: 0.203
#   IK1: 0.126
#   IbCa: 0.068
#   IpCa: 0.058
#   IbNa: 0.023
# Drug: Mibefradil I
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.879
#   IKs: 0.827
#   IpK: 0.609
#   IKr: 0.330
#   INaK: 0.309
#   INaCa: 0.191
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Mitoxantrone
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.879
#   IKs: 0.823
#   IpK: 0.588
#   IKr: 0.356
#   INaK: 0.318
#   INaCa: 0.200
#   IK1: 0.120
#   IbCa: 0.069
#   IpCa: 0.057
#   IbNa: 0.023
# Drug: Moxifloxacin I
#   INa: 1.000
#   Ito: 0.956
#   ICaL: 0.879
#   IKs: 0.841
#   IpK: 0.595
#   INaK: 0.319
#   IKr: 0.310
#   INaCa: 0.184
#   IK1: 0.118
#   IbCa: 0.066
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Moxifloxacin II
#   INa: 1.000
#   Ito: 0.956
#   ICaL: 0.878
#   IKs: 0.841
#   IpK: 0.596
#   INaK: 0.319
#   IKr: 0.308
#   INaCa: 0.184
#   IK1: 0.118
#   IbCa: 0.066
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Nifedinipine
#   INa: 1.000
#   Ito: 0.986
#   ICaL: 0.926
#   IK1: 0.737
#   IKr: 0.696
#   INaCa: 0.655
#   IKs: 0.600
#   INaK: 0.484
#   IbCa: 0.253
#   IpK: 0.212
#   IbNa: 0.092
#   IpCa: 0.064
# Drug: Nilotinib I
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.876
#   IKs: 0.846
#   IpK: 0.619
#   INaK: 0.310
#   IKr: 0.275
#   INaCa: 0.175
#   IK1: 0.116
#   IbCa: 0.061
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Nimodipine
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.879
#   IKs: 0.824
#   IpK: 0.591
#   IKr: 0.352
#   INaK: 0.316
#   INaCa: 0.198
#   IK1: 0.120
#   IbCa: 0.068
#   IpCa: 0.057
#   IbNa: 0.023
# Drug: Nitrendipine
#   INa: 1.000
#   Ito: 0.958
#   ICaL: 0.881
#   IKs: 0.805
#   IpK: 0.512
#   IKr: 0.437
#   INaK: 0.344
#   INaCa: 0.241
#   IK1: 0.126
#   IbCa: 0.087
#   IpCa: 0.059
#   IbNa: 0.030
# Drug: Paliperidone
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.877
#   IKs: 0.837
#   IpK: 0.617
#   INaK: 0.308
#   IKr: 0.299
#   INaCa: 0.182
#   IK1: 0.118
#   IbCa: 0.062
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Paroxetine
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.611
#   IKr: 0.328
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Pentobarbital
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.610
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Phenytoin
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.879
#   IKs: 0.808
#   IpK: 0.518
#   IKr: 0.430
#   INaK: 0.350
#   INaCa: 0.240
#   IK1: 0.131
#   IbCa: 0.088
#   IpCa: 0.060
#   IbNa: 0.030
# Drug: Pimozide
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.828
#   IpK: 0.612
#   IKr: 0.326
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Piperacillin
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.824
#   IpK: 0.577
#   IKr: 0.365
#   INaK: 0.328
#   INaCa: 0.206
#   IK1: 0.123
#   IbCa: 0.073
#   IpCa: 0.058
#   IbNa: 0.025
# Drug: Primidone
#   INa: 1.000
#   Ito: 0.952
#   ICaL: 0.878
#   IKs: 0.828
#   IpK: 0.614
#   IKr: 0.327
#   INaK: 0.310
#   INaCa: 0.191
#   IK1: 0.121
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Procainamide
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.839
#   IpK: 0.547
#   IKr: 0.352
#   INaK: 0.348
#   INaCa: 0.208
#   IK1: 0.131
#   IbCa: 0.079
#   IpCa: 0.060
#   IbNa: 0.027
# Drug: Quinidine
#   INa: 1.000
#   Ito: 0.861
#   IKs: 0.847
#   ICaL: 0.846
#   IpK: 0.706
#   INaK: 0.375
#   IK1: 0.309
#   INaCa: 0.277
#   IbCa: 0.088
#   IpCa: 0.068
#   IKr: 0.034
#   IbNa: 0.030
# Drug: Raltegravir
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.879
#   IKs: 0.826
#   IpK: 0.600
#   IKr: 0.340
#   INaK: 0.313
#   INaCa: 0.194
#   IK1: 0.120
#   IbCa: 0.066
#   IpCa: 0.057
#   IbNa: 0.023
# Drug: Ribavirin
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.879
#   IKs: 0.828
#   IpK: 0.595
#   IKr: 0.340
#   INaK: 0.316
#   INaCa: 0.194
#   IK1: 0.120
#   IbCa: 0.067
#   IpCa: 0.057
#   IbNa: 0.023
# Drug: Risperidone
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.828
#   IpK: 0.611
#   IKr: 0.326
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Sertindole I
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.831
#   IpK: 0.613
#   IKr: 0.318
#   INaK: 0.308
#   INaCa: 0.187
#   IK1: 0.119
#   IbCa: 0.063
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Sertindole II
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.874
#   IKs: 0.851
#   IpK: 0.626
#   INaK: 0.309
#   IKr: 0.254
#   INaCa: 0.174
#   IK1: 0.116
#   IbCa: 0.059
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Sitagliptin
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.610
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.190
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Solifenacin
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.830
#   IpK: 0.612
#   IKr: 0.322
#   INaK: 0.308
#   INaCa: 0.188
#   IK1: 0.119
#   IbCa: 0.063
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Sotalol I
#   INa: 1.000
#   Ito: 0.957
#   ICaL: 0.878
#   IKs: 0.849
#   IpK: 0.594
#   INaK: 0.321
#   IKr: 0.289
#   INaCa: 0.178
#   IK1: 0.117
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Sotalol II
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.875
#   IKs: 0.847
#   IpK: 0.624
#   INaK: 0.309
#   IKr: 0.267
#   INaCa: 0.177
#   IK1: 0.117
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Sparfloxacin I
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.878
#   IKs: 0.839
#   IpK: 0.610
#   INaK: 0.311
#   IKr: 0.302
#   INaCa: 0.181
#   IK1: 0.118
#   IbCa: 0.063
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Sparfloxacin II
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.878
#   IKs: 0.838
#   IpK: 0.610
#   INaK: 0.311
#   IKr: 0.304
#   INaCa: 0.181
#   IK1: 0.118
#   IbCa: 0.063
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Sunitinib
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.829
#   IpK: 0.612
#   IKr: 0.325
#   INaK: 0.308
#   INaCa: 0.189
#   IK1: 0.119
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Telbivudine
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.831
#   IpK: 0.605
#   IKr: 0.325
#   INaK: 0.313
#   INaCa: 0.189
#   IK1: 0.119
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: Terfenadine I
#   INa: 1.000
#   Ito: 0.953
#   ICaL: 0.876
#   IKs: 0.842
#   IpK: 0.621
#   INaK: 0.309
#   IKr: 0.284
#   INaCa: 0.180
#   IK1: 0.117
#   IbCa: 0.061
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Terfenadine II
#   INa: 1.000
#   Ito: 0.956
#   ICaL: 0.875
#   IKs: 0.870
#   IpK: 0.616
#   INaK: 0.315
#   IKr: 0.201
#   INaCa: 0.155
#   IK1: 0.114
#   IbCa: 0.060
#   IpCa: 0.057
#   IbNa: 0.020
# Drug: Terodiline
#   INa: 1.000
#   Ito: 0.955
#   ICaL: 0.877
#   IKs: 0.849
#   IpK: 0.613
#   INaK: 0.312
#   IKr: 0.273
#   INaCa: 0.172
#   IK1: 0.116
#   IbCa: 0.062
#   IpCa: 0.057
#   IbNa: 0.021
# Drug: Thioridazine
#   INa: 1.000
#   Ito: 0.912
#   IKs: 0.890
#   ICaL: 0.869
#   IpK: 0.618
#   INaK: 0.377
#   INaCa: 0.186
#   IK1: 0.181
#   IKr: 0.134
#   IbCa: 0.082
#   IpCa: 0.065
#   IbNa: 0.027
# Drug: Verapamil I
#   INa: 1.000
#   Ito: 0.965
#   ICaL: 0.884
#   IKs: 0.838
#   IKr: 0.432
#   INaK: 0.393
#   IpK: 0.351
#   INaCa: 0.280
#   IK1: 0.158
#   IbCa: 0.112
#   IpCa: 0.058
#   IbNa: 0.039
# Drug: Verapamil III
#   INa: 1.000
#   Ito: 0.961
#   ICaL: 0.881
#   IKs: 0.800
#   IKr: 0.484
#   IpK: 0.398
#   INaK: 0.379
#   INaCa: 0.290
#   IK1: 0.151
#   IbCa: 0.110
#   IpCa: 0.060
#   IbNa: 0.039
# Drug: Voriconazole
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.879
#   IKs: 0.828
#   IpK: 0.605
#   IKr: 0.332
#   INaK: 0.311
#   INaCa: 0.191
#   IK1: 0.119
#   IbCa: 0.065
#   IpCa: 0.057
#   IbNa: 0.022
# Drug: test1(cisapride)
#   INa: 1.000
#   Ito: 0.953
#   IKs: 0.876
#   ICaL: 0.870
#   IpK: 0.636
#   INaK: 0.309
#   INaCa: 0.156
#   IKr: 0.154
#   IK1: 0.113
#   IpCa: 0.057
#   IbCa: 0.057
#   IbNa: 0.019
# Drug: test2(verapamil)
#   INa: 1.000
#   Ito: 0.986
#   ICaL: 0.917
#   IK1: 0.812
#   INaCa: 0.701
#   IKr: 0.595
#   INaK: 0.538
#   IKs: 0.513
#   IbCa: 0.307
#   IpK: 0.141
#   IbNa: 0.111
#   IpCa: 0.064
# Drug: test3(none)
#   INa: 1.000
#   Ito: 0.954
#   ICaL: 0.878
#   IKs: 0.827
#   IpK: 0.611
#   IKr: 0.329
#   INaK: 0.308
#   INaCa: 0.191
#   IK1: 0.120
#   IbCa: 0.064
#   IpCa: 0.057
#   IbNa: 0.022
